# %%
import matplotlib.pyplot as plt
import numpy as np
import math

i=100
ii=[j for j in range(i)]
iii=np.array(ii)

x=np.arange(0,3*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)
#ll=[np.sin(x) for x ]    
#lll=np.array(ll)
#plt.plot(ii,lll)
plt.show
